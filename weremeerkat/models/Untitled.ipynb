# %%
from benchmarks import benchmark, train, test, sample_sub, sort_ads
from models import VeryNaiveBayes, HomeMadeNaiveBayes
from utils import logger
import numpy as np
import pandas as pd

model = VeryNaiveBayes()
hnb = HomeMadeNaiveBayes()
# Out:
# 2016-10-22 23:37:57,001 - utils - INFO - ================START=================

# %%
events = pd.read_csv('../../data/raw/events.csv')
# Out:
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
events
# Out:
#           display_id            uuid  document_id   timestamp platform  \
# 0                  1  cb8c55702adb93       379743          61        3
# 1                  2  79a85fa78311b9      1794259          81        2
# 2                  3  822932ce3d8757      1179111         182        2
# 3                  4  85281d0a49f7ac      1777797         234        2
# 4                  5  8d0daef4bf5b56       252458         338        2
# 5                  6  7765b4faae4ad4      1773517         395        3
# 6                  7  2cc3f6457d16da      1149661         602        2
# 7                  8  166fc654d73c98      1330329         638        2
# 8                  9  9dddccf70f6067      1772126         667        1
# 9                 10  b09a0e92aa4d17       157455         693        1
# 10                11  602e210c5831e5      1773230         710        3
# 11                12  6fa993bd0e0157       892701         718        1
# ...

# %%
df1 = pd.DataFrame({'a': [1, 2], 'b':[4,5]})
df2 = pd.DataFrame({'a': [9,4], 'b':[9,5]})
df1.append(df2)
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 0  9  9
# 1  4  5

# %%
m[m.clicked.isnull()]
# Out:
# Empty DataFrame
# Columns: [display_id, ad_id, clicked, uuid, document_id, timestamp, platform, geo_location]
# Index: []

# %%
m = pd.merge(train, events, on='display_id')

# %%
m.groupby('platform').clicked.mean()
# Out:
# platform
# 1     0.174638
# 2     0.217605
# 3     0.180366
# 1     0.174819
# 2     0.218074
# 3     0.179194
# \N    0.166667
# Name: clicked, dtype: float64

# %%
# test 16874594
# train   
m[]
# Out:
#           display_id   ad_id  clicked
# 0                  1   42337        0
# 1                  1  139684        0
# 2                  1  144739        1
# 3                  1  156824        0
# 4                  1  279295        0
# 5                  1  296965        0
# 6                  2  125211        0
# 7                  2  156535        0
# 8                  2  169564        0
# 9                  2  308455        1
# 10                 3   71547        0
# 11                 3   95814        0
# 12                 3  152141        0
# 13                 3  183846        0
# 14                 3  228657        1
# 15                 3  250082        0
# 16                 4  149930        0
# 17                 4  153623        1
# 18                 4  184709        0
# 19                 4  186849        0
# 20                 4  233730        0
# 21                 5   54606        0
# 22                 5  162868        0
# 23                 5  184548        0
# ...
